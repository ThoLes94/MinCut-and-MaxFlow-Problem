# %%
import csv
import math
import sys, time
import networkx as nx
from pyomo.opt import SolverStatus, TerminationCondition
from pyomo.environ import *

# %%
G = nx.Graph()
pos = {}
site = {}

with open('nodes_cost266.csv', 'r') as f_node:
    reader = csv.DictReader(f_node, delimiter=';', quotechar="'")
    for row in reader:
        node = int(row['node'])
        site_node = row['site']
        x_coord = float(row['X'])
        y_coord = float(row['Y'])
        G.add_node(node,site=site_node)
        pos[node] = [x_coord,y_coord]
        site[node] = site_node

# %%
with open('edges_cost266.csv', 'r') as f_edge:
    reader = csv.DictReader(f_edge, delimiter=';', quotechar="'")
    for row in reader:
        nodeA = int(row['nodeA'])
        nodeB = int(row['nodeB'])
        G.add_edge(nodeA,nodeB)        
        G[nodeA][nodeB]['capa'] = float(row['capa'])

# %%
H = nx.DiGraph(G)
capa = {}

for (u,v) in G.edges():
    capa[(u,v)] = G[u][v]['capa']
    capa[(v,u)] = G[u][v]['capa']

# %%
K = nx.DiGraph()

with open('demand_cost266.csv', 'r') as f_demand:
    reader = csv.DictReader(f_demand, delimiter=';', quotechar="'")
    for row in reader:
        nodeA = int(row['nodeA'])
        nodeB = int(row['nodeB'])
        if nodeA > nodeB:
            tmp = nodeA
            nodeA = nodeB
            nodeB = tmp
            
        K.add_edge(nodeA,nodeB)                    
        K[nodeA][nodeB]['demand'] = float(row['demand'])/25.0 #Pour arriver à des taux de charges raisonnables

# %%
print(len(G.nodes()),'nodes')
print(len(G.edges()),'edges')
print(len(K.edges()),'demands')
# Out:
# 37 nodes
# 57 edges
# 36 demands

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.figure(figsize=(10,10));
plt.axis('off')

nx.draw_networkx_labels(G,pos,labels=site,font_size=10,font_color='black')

nx.draw(G, pos=pos, node_size=500, node_color='lightgrey', edge_color='grey')

nx.draw_networkx_labels(K,pos,labels=site,font_size=10,font_color='black')  
nx.draw_networkx_nodes(K, pos=pos, node_size=600, node_color='orange',node_shape='s')

# %%
# +++ Flow Conservation constraints +++
def flowConservation(model, node, o, d):
    inFlow = sum(
        model.flow[i, j, o, d]
        for (i, j) in model.arcs
        if j == node
    )
    outFlow = sum(
        model.flow[i, j, o, d]
        for (i, j) in model.arcs
        if i == node
    )
    if node == o:
        return (inFlow - outFlow + K[o][d]['demand'] == 0)
    elif node == d:
        return (inFlow - outFlow - K[o][d]['demand'] == 0)
    else:
        return (inFlow == outFlow)

# %%
#+++ Capacity constraints +++
def linkCapacity(model, i, j):
    expression = sum(model.flow[i,j,o,d] + model.flow[j,i,o,d] for (o,d) in model.demands)<= model.capa[i,j] * model.gamma
    return expression

# %%
solver = 'cplex'

print('>>> Loading optimization model')

model = ConcreteModel()

model.dual = Suffix(direction=Suffix.IMPORT)

model.nodes   = H.nodes()
model.links   = G.edges()
model.arcs    = H.edges()
model.demands = K.edges()

model.index1 = Set(initialize=[(u, o, d) for u in model.nodes for (o, d) in model.demands])
model.index2 = Set(initialize=[(u, v, o, d) for (u, v) in model.arcs for (o, d) in model.demands])

model.capa = Param(model.arcs, initialize=capa)

model.flow  = Var(model.index2, domain=NonNegativeReals)
model.gamma = Var(domain=NonNegativeReals)

model.objective = Objective(rule=lambda m: m.gamma, sense=minimize)

model.flowConserv = Constraint(model.index1, rule=flowConservation)

model.linkCapa = Constraint(model.links, rule=linkCapacity)
# Out:
# >>> Loading optimization model

# %%
print('>>> Solving optimization model')
    
# model.preprocess()

optim = SolverFactory(solver)
    
start_time = time.time()

results = optim.solve(model)
    
cpu_time = time.time() - start_time

print('+ TERM STAT:',results.solver.status)
print('+ TERM COND:',results.solver.termination_condition)
    
print('+ CPU  TIME = {0:.2f} s'.format(cpu_time))

if results.solver.status == SolverStatus.ok and results.solver.termination_condition != TerminationCondition.infeasible:
    print('+ OPT VAL  = {0:.8f}'.format(model.gamma.value))
    print('+ LWR BND  = {0:.2f}'.format(results.Problem._list[0]['Lower bound']))
# Out:
# >>> Solving optimization model
# + TERM STAT: ok
# + TERM COND: optimal
# + CPU  TIME = 1.82 s
# + OPT VAL  = 0.68820000
# + LWR BND  = 0.69

# %%
epsilon = 1.0e-06

load = {}
    
for (u,v) in G.edges():
    TotalFlow = 0.0
    for (o,d) in K.edges():
        TotalFlow += model.flow[u,v,o,d].value  #On somme pour chaque lien le flow qui passe
        TotalFlow += model.flow[v,u,o,d].value
    G[u][v]['flow'] = TotalFlow    
    if TotalFlow > epsilon:
        load[(u,v)] = 100*TotalFlow/model.capa[(u,v)]
        print('link ({0:10s},{1:10s}):\tflow = {2:8f} / capacity = {3:8f} -> load = {4:.2f} %'.format(site[u],site[v],TotalFlow,model.capa[(u,v)],load[(u,v)]))
        #print('link ({0:10s},{1:10s}):\tflow = {2:8f} / capacity = {3:8f} -> load = {4:.2f} %'.format(site[u],site[v],TotalFlow,model.capa[(u,v)],100*TotalFlow/model.capa[(u,v)]))
    else:
        load[(u,v)] = 0.0
# Out:
# link (Amsterdam ,Brussels  ):	flow = 137.640000 / capacity = 200.000000 -> load = 68.82 %
# link (Amsterdam ,London    ):	flow = 130.830000 / capacity = 250.000000 -> load = 52.33 %
# link (Amsterdam ,Glasgow   ):	flow = 172.050000 / capacity = 250.000000 -> load = 68.82 %
# link (Amsterdam ,Hamburg   ):	flow = 106.500000 / capacity = 250.000000 -> load = 42.60 %
# link (Athens    ,Palermo   ):	flow = 25.840000 / capacity = 300.000000 -> load = 8.61 %
# link (Athens    ,Zagreb    ):	flow = 37.980000 / capacity = 250.000000 -> load = 15.19 %
# link (Athens    ,Sofia     ):	flow = 61.860000 / capacity = 200.000000 -> load = 30.93 %
# link (Barcelona ,Seville   ):	flow = 98.750000 / capacity = 200.000000 -> load = 49.37 %
# link (Barcelona ,Madrid    ):	flow = 51.770000 / capacity = 200.000000 -> load = 25.89 %
# link (Barcelona ,Marseille ):	flow = 100.040000 / capacity = 200.000000 -> load = 50.02 %
# link (Belgrade  ,Budapest  ):	flow = 68.820000 / capacity = 100.000000 -> load = 68.82 %
# link (Belgrade  ,Zagreb    ):	flow = 6.960000 / capacity = 250.000000 -> load = 2.78 %
# link (Belgrade  ,Sofia     ):	flow = 61.860000 / capacity = 200.000000 -> load = 30.93 %
# link (Berlin    ,Munich    ):	flow = 103.230000 / capacity = 150.000000 -> load = 68.82 %
# link (Berlin    ,Copenhagen):	flow = 68.820000 / capacity = 100.000000 -> load = 68.82 %
# link (Berlin    ,Warsaw    ):	flow = 172.050000 / capacity = 250.000000 -> load = 68.82 %
# link (Berlin    ,Prague    ):	flow = 129.270000 / capacity = 200.000000 -> load = 64.64 %
# link (Berlin    ,Hamburg   ):	flow = 37.890000 / capacity = 200.000000 -> load = 18.94 %
# link (Birmingham,London    ):	flow = 34.410000 / capacity = 50.000000 -> load = 68.82 %
# link (Birmingham,Glasgow   ):	flow = 34.410000 / capacity = 50.000000 -> load = 68.82 %
# link (Bordeaux  ,Paris     ):	flow = 34.410000 / capacity = 50.000000 -> load = 68.82 %
# link (Bordeaux  ,Madrid    ):	flow = 77.370000 / capacity = 250.000000 -> load = 30.95 %
# link (Bordeaux  ,Marseille ):	flow = 42.960000 / capacity = 250.000000 -> load = 17.18 %
# link (Brussels  ,Paris     ):	flow = 57.690000 / capacity = 300.000000 -> load = 19.23 %
# link (Brussels  ,Dusseldorf):	flow = 79.950000 / capacity = 150.000000 -> load = 53.30 %
# link (Budapest  ,Krakow    ):	flow = 35.330000 / capacity = 300.000000 -> load = 11.78 %
# link (Budapest  ,Prague    ):	flow = 33.490000 / capacity = 150.000000 -> load = 22.33 %
# link (Copenhagen,Stockholm ):	flow = 34.410000 / capacity = 50.000000 -> load = 68.82 %
# link (Copenhagen,Oslo      ):	flow = 34.410000 / capacity = 250.000000 -> load = 13.76 %
# link (Dublin    ,London    ):	flow = 68.820000 / capacity = 100.000000 -> load = 68.82 %
# link (Dublin    ,Glasgow   ):	flow = 110.060000 / capacity = 200.000000 -> load = 55.03 %
# link (Dusseldorf,Frankfurt ):	flow = 79.950000 / capacity = 250.000000 -> load = 31.98 %
# link (Frankfurt ,Munich    ):	flow = 81.920000 / capacity = 200.000000 -> load = 40.96 %
# link (Frankfurt ,Strasbourg):	flow = 152.980000 / capacity = 300.000000 -> load = 50.99 %
# link (Frankfurt ,Hamburg   ):	flow = 68.820000 / capacity = 100.000000 -> load = 68.82 %
# link (Helsinki  ,Stockholm ):	flow = 34.410000 / capacity = 250.000000 -> load = 13.76 %
# link (Helsinki  ,Oslo      ):	flow = 34.410000 / capacity = 150.000000 -> load = 22.94 %
# link (Helsinki  ,Warsaw    ):	flow = 81.320000 / capacity = 300.000000 -> load = 27.11 %
# link (Krakow    ,Warsaw    ):	flow = 35.330000 / capacity = 150.000000 -> load = 23.55 %
# link (Lisbon    ,London    ):	flow = 34.410000 / capacity = 50.000000 -> load = 68.82 %
# link (Lisbon    ,Madrid    ):	flow = 52.960000 / capacity = 200.000000 -> load = 26.48 %
# link (Lisbon    ,Seville   ):	flow = 72.050000 / capacity = 300.000000 -> load = 24.02 %
# link (London    ,Paris     ):	flow = 26.690000 / capacity = 150.000000 -> load = 17.79 %
# link (Lyon      ,Paris     ):	flow = 71.080000 / capacity = 200.000000 -> load = 35.54 %
# link (Lyon      ,Zurich    ):	flow = 47.330000 / capacity = 100.000000 -> load = 47.33 %
# link (Lyon      ,Marseille ):	flow = 118.410000 / capacity = 200.000000 -> load = 59.20 %
# link (Marseille ,Rome      ):	flow = 172.050000 / capacity = 250.000000 -> load = 68.82 %
# link (Milan     ,Munich    ):	flow = 103.000000 / capacity = 200.000000 -> load = 51.50 %
# link (Milan     ,Rome      ):	flow = 74.420000 / capacity = 150.000000 -> load = 49.61 %
# link (Milan     ,Zurich    ):	flow = 84.540000 / capacity = 250.000000 -> load = 33.82 %
# link (Munich    ,Vienna    ):	flow = 81.830000 / capacity = 250.000000 -> load = 32.73 %
# link (Palermo   ,Rome      ):	flow = 25.840000 / capacity = 100.000000 -> load = 25.84 %
# link (Paris     ,Strasbourg):	flow = 21.110000 / capacity = 100.000000 -> load = 21.11 %
# link (Prague    ,Vienna    ):	flow = 95.780000 / capacity = 200.000000 -> load = 47.89 %
# link (Rome      ,Zagreb    ):	flow = 79.350000 / capacity = 150.000000 -> load = 52.90 %
# link (Strasbourg,Zurich    ):	flow = 131.870000 / capacity = 200.000000 -> load = 65.93 %
# link (Vienna    ,Zagreb    ):	flow = 34.410000 / capacity = 50.000000 -> load = 68.82 %

# %%
for (o,d) in K.edges():
    print('demand ({0:s},{1:s}): {2:f}'.format(site[o],site[d],K[o][d]['demand']*model.gamma.value))
    for (u,v) in model.arcs:
        if model.flow[u,v,o,d].value > epsilon:
            print('\tarc ({0:s},{1:s}): flow = {2:f}'.format(site[u],site[v],model.flow[u,v,o,d].value))
# Out:
# demand (Athens,Dublin): 0.991008
# 	arc (Amsterdam,London): flow = 1.440000
# 	arc (Athens,Sofia): flow = 1.440000
# 	arc (Belgrade,Budapest): flow = 1.440000
# 	arc (Berlin,Hamburg): flow = 1.440000
# 	arc (Budapest,Prague): flow = 1.440000
# 	arc (Hamburg,Amsterdam): flow = 1.440000
# 	arc (London,Dublin): flow = 1.440000
# 	arc (Prague,Berlin): flow = 1.440000
# 	arc (Sofia,Belgrade): flow = 1.440000
# demand (Athens,Frankfurt): 6.992112
# 	arc (Athens,Zagreb): flow = 10.160000
# 	arc (Milan,Munich): flow = 10.160000
# 	arc (Munich,Frankfurt): flow = 10.160000
# 	arc (Rome,Milan): flow = 10.160000
# 	arc (Zagreb,Rome): flow = 10.160000
# demand (Athens,Glasgow): 9.166824
# 	arc (Amsterdam,London): flow = 13.320000
# 	arc (Athens,Sofia): flow = 13.320000
# 	arc (Belgrade,Budapest): flow = 13.320000
# 	arc (Berlin,Hamburg): flow = 13.320000
# 	arc (Budapest,Prague): flow = 13.320000
# 	arc (Dublin,Glasgow): flow = 13.320000
# 	arc (Hamburg,Amsterdam): flow = 13.320000
# 	arc (London,Dublin): flow = 13.320000
# 	arc (Prague,Berlin): flow = 13.320000
# 	arc (Sofia,Belgrade): flow = 13.320000
# demand (Athens,Helsinki): 1.514040
# 	arc (Athens,Sofia): flow = 2.200000
# 	arc (Belgrade,Budapest): flow = 2.200000
# 	arc (Budapest,Krakow): flow = 2.200000
# 	arc (Krakow,Warsaw): flow = 2.200000
# 	arc (Sofia,Belgrade): flow = 2.200000
# 	arc (Warsaw,Helsinki): flow = 2.200000
# demand (Athens,Lisbon): 2.615160
# 	arc (Athens,Palermo): flow = 3.800000
# 	arc (Barcelona,Seville): flow = 3.800000
# 	arc (Marseille,Barcelona): flow = 3.800000
# 	arc (Palermo,Rome): flow = 3.800000
# 	arc (Rome,Marseille): flow = 3.800000
# 	arc (Seville,Lisbon): flow = 3.800000
# demand (Athens,Rome): 10.653336
# 	arc (Athens,Palermo): flow = 15.480000
# 	arc (Palermo,Rome): flow = 15.480000
# demand (Athens,Seville): 4.514592
# 	arc (Athens,Palermo): flow = 6.560000
# 	arc (Barcelona,Seville): flow = 6.560000
# 	arc (Marseille,Barcelona): flow = 6.560000
# 	arc (Palermo,Rome): flow = 6.560000
# 	arc (Rome,Marseille): flow = 6.560000
# demand (Athens,Warsaw): 11.754456
# 	arc (Athens,Sofia): flow = 17.080000
# 	arc (Belgrade,Budapest): flow = 17.080000
# 	arc (Budapest,Krakow): flow = 17.080000
# 	arc (Krakow,Warsaw): flow = 17.080000
# 	arc (Sofia,Belgrade): flow = 17.080000
# demand (Dublin,Frankfurt): 4.074144
# 	arc (Amsterdam,Hamburg): flow = 5.920000
# 	arc (Dublin,Glasgow): flow = 5.920000
# 	arc (Glasgow,Amsterdam): flow = 5.920000
# 	arc (Hamburg,Frankfurt): flow = 5.920000
# demand (Dublin,Glasgow): 12.112320
# 	arc (Dublin,Glasgow): flow = 17.600000
# demand (Dublin,Helsinki): 0.798312
# 	arc (Amsterdam,Hamburg): flow = 1.160000
# 	arc (Berlin,Warsaw): flow = 1.160000
# 	arc (Dublin,Glasgow): flow = 1.160000
# 	arc (Glasgow,Amsterdam): flow = 1.160000
# 	arc (Hamburg,Berlin): flow = 1.160000
# 	arc (Warsaw,Helsinki): flow = 1.160000
# demand (Dublin,Lisbon): 1.596624
# 	arc (Birmingham,London): flow = 2.320000
# 	arc (Dublin,Glasgow): flow = 2.320000
# 	arc (Glasgow,Birmingham): flow = 2.320000
# 	arc (London,Lisbon): flow = 2.320000
# demand (Dublin,Rome): 3.523584
# 	arc (Amsterdam,Brussels): flow = 5.120000
# 	arc (Brussels,Dusseldorf): flow = 5.120000
# 	arc (Dublin,Glasgow): flow = 5.120000
# 	arc (Dusseldorf,Frankfurt): flow = 5.120000
# 	arc (Frankfurt,Strasbourg): flow = 5.120000
# 	arc (Glasgow,Amsterdam): flow = 5.120000
# 	arc (Lyon,Marseille): flow = 5.120000
# 	arc (Marseille,Rome): flow = 5.120000
# 	arc (Strasbourg,Zurich): flow = 5.120000
# 	arc (Zurich,Lyon): flow = 5.120000
# demand (Dublin,Seville): 2.477520
# 	arc (Birmingham,London): flow = 3.600000
# 	arc (Dublin,Glasgow): flow = 3.600000
# 	arc (Glasgow,Birmingham): flow = 3.600000
# 	arc (Lisbon,Seville): flow = 3.600000
# 	arc (London,Lisbon): flow = 3.600000
# demand (Dublin,Warsaw): 4.789872
# 	arc (Amsterdam,Brussels): flow = 6.960000
# 	arc (Belgrade,Budapest): flow = 6.960000
# 	arc (Birmingham,London): flow = 6.960000
# 	arc (Brussels,Dusseldorf): flow = 6.960000
# 	arc (Budapest,Krakow): flow = 6.960000
# 	arc (Dublin,Glasgow): flow = 6.960000
# 	arc (Dusseldorf,Frankfurt): flow = 6.960000
# 	arc (Frankfurt,Strasbourg): flow = 6.960000
# 	arc (Glasgow,Birmingham): flow = 6.960000
# 	arc (Krakow,Warsaw): flow = 6.960000
# 	arc (London,Amsterdam): flow = 6.960000
# 	arc (Lyon,Marseille): flow = 6.960000
# 	arc (Marseille,Rome): flow = 6.960000
# 	arc (Paris,Lyon): flow = 6.960000
# 	arc (Rome,Zagreb): flow = 6.960000
# 	arc (Strasbourg,Paris): flow = 6.960000
# 	arc (Zagreb,Belgrade): flow = 6.960000
# demand (Frankfurt,Glasgow): 39.117288
# 	arc (Amsterdam,Glasgow): flow = 56.840000
# 	arc (Frankfurt,Hamburg): flow = 56.840000
# 	arc (Hamburg,Amsterdam): flow = 56.840000
# demand (Frankfurt,Helsinki): 5.202792
# 	arc (Athens,Sofia): flow = 5.030000
# 	arc (Belgrade,Budapest): flow = 5.030000
# 	arc (Berlin,Copenhagen): flow = 2.530000
# 	arc (Budapest,Krakow): flow = 5.030000
# 	arc (Copenhagen,Oslo): flow = 2.530000
# 	arc (Frankfurt,Strasbourg): flow = 7.560000
# 	arc (Frankfurt,Hamburg): flow = 0.105000
# 	arc (Hamburg,Frankfurt): flow = 0.105000
# 	arc (Krakow,Warsaw): flow = 5.030000
# 	arc (Lyon,Marseille): flow = 7.560000
# 	arc (Marseille,Rome): flow = 7.560000
# 	arc (Milan,Munich): flow = 2.530000
# 	arc (Munich,Berlin): flow = 2.530000
# 	arc (Oslo,Helsinki): flow = 2.530000
# 	arc (Rome,Milan): flow = 2.530000
# 	arc (Rome,Zagreb): flow = 5.030000
# 	arc (Sofia,Belgrade): flow = 5.030000
# 	arc (Strasbourg,Zurich): flow = 7.560000
# 	arc (Warsaw,Helsinki): flow = 5.030000
# 	arc (Zagreb,Athens): flow = 5.030000
# 	arc (Zurich,Lyon): flow = 7.560000
# demand (Frankfurt,Lisbon): 8.561208
# 	arc (Barcelona,Seville): flow = 12.440000
# 	arc (Frankfurt,Strasbourg): flow = 12.440000
# 	arc (Lyon,Marseille): flow = 12.440000
# 	arc (Marseille,Barcelona): flow = 12.440000
# 	arc (Seville,Lisbon): flow = 12.440000
# 	arc (Strasbourg,Zurich): flow = 12.440000
# 	arc (Zurich,Lyon): flow = 12.440000
# demand (Frankfurt,Rome): 27.583056
# 	arc (Frankfurt,Strasbourg): flow = 40.080000
# 	arc (Lyon,Marseille): flow = 19.100000
# 	arc (Marseille,Rome): flow = 19.100000
# 	arc (Milan,Rome): flow = 20.980000
# 	arc (Strasbourg,Zurich): flow = 40.080000
# 	arc (Zurich,Lyon): flow = 19.100000
# 	arc (Zurich,Milan): flow = 20.980000
# demand (Frankfurt,Seville): 13.764000
# 	arc (Amsterdam,Brussels): flow = 5.850000
# 	arc (Barcelona,Seville): flow = 20.000000
# 	arc (Brussels,Paris): flow = 5.850000
# 	arc (Frankfurt,Strasbourg): flow = 14.150000
# 	arc (Frankfurt,Hamburg): flow = 5.850000
# 	arc (Hamburg,Amsterdam): flow = 5.850000
# 	arc (Lyon,Marseille): flow = 20.000000
# 	arc (Marseille,Barcelona): flow = 20.000000
# 	arc (Paris,Lyon): flow = 20.000000
# 	arc (Strasbourg,Paris): flow = 14.150000
# demand (Frankfurt,Warsaw): 38.924592
# 	arc (Berlin,Copenhagen): flow = 34.410000
# 	arc (Berlin,Warsaw): flow = 22.150000
# 	arc (Copenhagen,Stockholm): flow = 34.410000
# 	arc (Frankfurt,Strasbourg): flow = 56.560000
# 	arc (Helsinki,Warsaw): flow = 34.410000
# 	arc (Milan,Munich): flow = 56.560000
# 	arc (Munich,Vienna): flow = 56.560000
# 	arc (Prague,Berlin): flow = 56.560000
# 	arc (Stockholm,Helsinki): flow = 34.410000
# 	arc (Strasbourg,Zurich): flow = 56.560000
# 	arc (Vienna,Prague): flow = 56.560000
# 	arc (Zurich,Milan): flow = 56.560000
# demand (Glasgow,Helsinki): 8.836488
# 	arc (Amsterdam,Hamburg): flow = 12.840000
# 	arc (Berlin,Copenhagen): flow = 12.840000
# 	arc (Copenhagen,Oslo): flow = 12.840000
# 	arc (Glasgow,Amsterdam): flow = 12.840000
# 	arc (Hamburg,Berlin): flow = 12.840000
# 	arc (Oslo,Helsinki): flow = 12.840000
# demand (Glasgow,Lisbon): 14.837592
# 	arc (Amsterdam,London): flow = 10.730000
# 	arc (Birmingham,London): flow = 10.830000
# 	arc (Bordeaux,Madrid): flow = 21.560000
# 	arc (Glasgow,Amsterdam): flow = 10.730000
# 	arc (Glasgow,Birmingham): flow = 10.830000
# 	arc (London,Paris): flow = 21.560000
# 	arc (Madrid,Lisbon): flow = 21.560000
# 	arc (Paris,Bordeaux): flow = 21.560000
# demand (Glasgow,Rome): 32.923488
# 	arc (Amsterdam,Brussels): flow = 47.840000
# 	arc (Barcelona,Marseille): flow = 12.850000
# 	arc (Bordeaux,Madrid): flow = 12.850000
# 	arc (Brussels,Paris): flow = 47.840000
# 	arc (Glasgow,Amsterdam): flow = 47.840000
# 	arc (Lyon,Marseille): flow = 34.990000
# 	arc (Madrid,Barcelona): flow = 12.850000
# 	arc (Marseille,Rome): flow = 47.840000
# 	arc (Paris,Bordeaux): flow = 12.850000
# 	arc (Paris,Lyon): flow = 34.990000
# demand (Glasgow,Seville): 21.747120
# 	arc (Amsterdam,Brussels): flow = 3.110000
# 	arc (Amsterdam,London): flow = 28.490000
# 	arc (Barcelona,Seville): flow = 3.110000
# 	arc (Brussels,Dusseldorf): flow = 3.110000
# 	arc (Dusseldorf,Frankfurt): flow = 3.110000
# 	arc (Frankfurt,Strasbourg): flow = 3.110000
# 	arc (Glasgow,Amsterdam): flow = 31.600000
# 	arc (Lisbon,Seville): flow = 28.490000
# 	arc (London,Lisbon): flow = 28.490000
# 	arc (Lyon,Marseille): flow = 3.110000
# 	arc (Marseille,Barcelona): flow = 3.110000
# 	arc (Strasbourg,Zurich): flow = 3.110000
# 	arc (Zurich,Lyon): flow = 3.110000
# demand (Glasgow,Warsaw): 44.567832
# 	arc (Amsterdam,Brussels): flow = 64.760000
# 	arc (Berlin,Warsaw): flow = 64.760000
# 	arc (Birmingham,London): flow = 10.700000
# 	arc (Brussels,Dusseldorf): flow = 64.760000
# 	arc (Dublin,London): flow = 54.060000
# 	arc (Dusseldorf,Frankfurt): flow = 64.760000
# 	arc (Frankfurt,Munich): flow = 64.760000
# 	arc (Glasgow,Birmingham): flow = 10.700000
# 	arc (Glasgow,Dublin): flow = 54.060000
# 	arc (London,Amsterdam): flow = 64.760000
# 	arc (Munich,Berlin): flow = 64.760000
# demand (Helsinki,Lisbon): 1.844376
# 	arc (Amsterdam,London): flow = 2.680000
# 	arc (Berlin,Hamburg): flow = 2.680000
# 	arc (Bordeaux,Madrid): flow = 2.680000
# 	arc (Hamburg,Amsterdam): flow = 2.680000
# 	arc (Helsinki,Warsaw): flow = 2.680000
# 	arc (London,Paris): flow = 2.680000
# 	arc (Lyon,Marseille): flow = 2.680000
# 	arc (Madrid,Lisbon): flow = 2.680000
# 	arc (Marseille,Bordeaux): flow = 2.680000
# 	arc (Paris,Lyon): flow = 2.680000
# 	arc (Warsaw,Berlin): flow = 2.680000
# demand (Helsinki,Rome): 4.817400
# 	arc (Berlin,Munich): flow = 7.000000
# 	arc (Frankfurt,Strasbourg): flow = 7.000000
# 	arc (Helsinki,Warsaw): flow = 7.000000
# 	arc (Milan,Rome): flow = 7.000000
# 	arc (Munich,Frankfurt): flow = 7.000000
# 	arc (Strasbourg,Zurich): flow = 7.000000
# 	arc (Warsaw,Berlin): flow = 7.000000
# 	arc (Zurich,Milan): flow = 7.000000
# demand (Helsinki,Seville): 2.752800
# 	arc (Amsterdam,Brussels): flow = 4.000000
# 	arc (Barcelona,Seville): flow = 4.000000
# 	arc (Berlin,Hamburg): flow = 4.000000
# 	arc (Brussels,Paris): flow = 4.000000
# 	arc (Copenhagen,Berlin): flow = 4.000000
# 	arc (Hamburg,Amsterdam): flow = 4.000000
# 	arc (Helsinki,Oslo): flow = 4.000000
# 	arc (Lyon,Marseille): flow = 4.000000
# 	arc (Marseille,Barcelona): flow = 4.000000
# 	arc (Oslo,Copenhagen): flow = 4.000000
# 	arc (Paris,Lyon): flow = 4.000000
# demand (Helsinki,Warsaw): 9.497160
# 	arc (Helsinki,Warsaw): flow = 13.800000
# demand (Lisbon,Rome): 9.414576
# 	arc (Barcelona,Marseille): flow = 13.680000
# 	arc (Lisbon,Madrid): flow = 13.680000
# 	arc (Madrid,Barcelona): flow = 13.680000
# 	arc (Marseille,Rome): flow = 13.680000
# demand (Lisbon,Seville): 16.324104
# 	arc (Lisbon,Seville): flow = 23.720000
# demand (Lisbon,Warsaw): 10.350528
# 	arc (Berlin,Copenhagen): flow = 15.040000
# 	arc (Bordeaux,Marseille): flow = 15.040000
# 	arc (Copenhagen,Oslo): flow = 15.040000
# 	arc (Helsinki,Warsaw): flow = 15.040000
# 	arc (Lisbon,Madrid): flow = 15.040000
# 	arc (Madrid,Bordeaux): flow = 15.040000
# 	arc (Marseille,Rome): flow = 15.040000
# 	arc (Milan,Munich): flow = 15.040000
# 	arc (Munich,Vienna): flow = 15.040000
# 	arc (Oslo,Helsinki): flow = 15.040000
# 	arc (Prague,Berlin): flow = 15.040000
# 	arc (Rome,Milan): flow = 15.040000
# 	arc (Vienna,Prague): flow = 15.040000
# demand (Rome,Seville): 16.241520
# 	arc (Barcelona,Seville): flow = 23.600000
# 	arc (Marseille,Barcelona): flow = 23.600000
# 	arc (Rome,Marseille): flow = 23.600000
# demand (Rome,Warsaw): 36.557184
# 	arc (Berlin,Warsaw): flow = 53.120000
# 	arc (Milan,Munich): flow = 18.710000
# 	arc (Munich,Berlin): flow = 28.940000
# 	arc (Prague,Berlin): flow = 24.180000
# 	arc (Rome,Milan): flow = 18.710000
# 	arc (Rome,Zagreb): flow = 34.410000
# 	arc (Vienna,Munich): flow = 10.230000
# 	arc (Vienna,Prague): flow = 24.180000
# 	arc (Zagreb,Vienna): flow = 34.410000
# demand (Seville,Warsaw): 17.370168
# 	arc (Amsterdam,Hamburg): flow = 2.450000
# 	arc (Athens,Sofia): flow = 22.790000
# 	arc (Barcelona,Madrid): flow = 25.240000
# 	arc (Belgrade,Budapest): flow = 22.790000
# 	arc (Berlin,Warsaw): flow = 21.180000
# 	arc (Bordeaux,Marseille): flow = 25.240000
# 	arc (Budapest,Krakow): flow = 4.060000
# 	arc (Budapest,Prague): flow = 18.730000
# 	arc (Hamburg,Berlin): flow = 2.450000
# 	arc (Krakow,Warsaw): flow = 4.060000
# 	arc (London,Amsterdam): flow = 2.450000
# 	arc (Lyon,Paris): flow = 2.450000
# 	arc (Madrid,Bordeaux): flow = 25.240000
# 	arc (Marseille,Lyon): flow = 2.450000
# 	arc (Marseille,Rome): flow = 22.790000
# 	arc (Paris,London): flow = 2.450000
# 	arc (Prague,Berlin): flow = 18.730000
# 	arc (Rome,Zagreb): flow = 22.790000
# 	arc (Seville,Barcelona): flow = 25.240000
# 	arc (Sofia,Belgrade): flow = 22.790000
# 	arc (Zagreb,Athens): flow = 22.790000

# %%
plt.figure(figsize=(10,10));
plt.axis('off')

colors = []
for (u,v) in G.edges():
    if load[(u,v)] > 100:
        colors.append('black')
    elif load[(u,v)] > 75:
        colors.append('red')
    elif load[(u,v)] > 50:
        colors.append('orange')
    elif load[(u,v)] >=25:
        colors.append('green')
    elif load[(u,v)] >=0:
        colors.append('lightgreen')
    else:
        colors.append('lightgrey')

    nx.draw_networkx_labels(G,pos,labels=site,font_size=10,font_color='black')
    nx.draw(G, pos=pos, node_size=500, node_color='lightgrey', edge_color=colors, width=4)

    nx.draw_networkx_labels(K,pos,labels=site,font_size=10,font_color='black')  
    nx.draw_networkx_nodes(K, pos=pos, node_size=600, node_color='orange',node_shape='s')
